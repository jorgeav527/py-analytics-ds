# %% [markdown]
# ### Pregunta 01
#
# 1. Generación de Datos: Crear un DataFrame de Pandas donde la columna RADIO contenga una secuencia numérica del 1 al 20 usando range().
# 2. Cálculo de Área: Crear la columna AREA aplicando la fórmula del área de un círculo ($\pi \cdot r^2$) utilizando cada valor de la columna RADIO.
# 3. Cálculo de Volumen: Crear la columna VOLUMEN aplicando la fórmula del volumen de una esfera ($\frac{4}{3} \cdot \pi \cdot r^3$). Reto: Para practicar la lógica de datos, extrae el radio a partir de la columna AREA calculada anteriormente ($r = \sqrt{Area/\pi}$).

# %% [markdown]
# 1. **Función de Área**:
#    $f(r) = \pi r^2$
#
# 2. **Función de Volumen**:
#    $g(r) = \frac{4}{3} \pi r^3$

# %% [markdown]
# ### Pregunta 02
#
# - Preparación del Entorno y Carga de datos del titanic `df = pd.read_csv('gapminder.csv')`
#
# "Vamos a analizar a Egipto. En el primer gráfico, muestra cómo ha crecido su población a lo largo de los años. En el segundo gráfico, muestra cómo ha evolucionado su esperanza de vida. ¿Crees que el aumento masivo de población ha frenado la mejora en la salud o ambos indicadores han crecido juntos?"

# %% [markdown]
# ### Pregunta 3:
#
# - Preparación del Entorno y Carga de datos del `df = sns.load_dataset('titanic')`
#
# "Si miramos a todos los pasajeros que abordaron el Titanic, ¿cuál era la edad más común? ¿Era un barco lleno de niños, de adultos jóvenes o de ancianos? Usa un gráfico de distribución para descubrir si la mayoría de la gente estaba en sus 20s-30s o si la distribución era uniforme."

# %% [markdown]
# ### Pregunta 4:
#
# - Preparación del Entorno y Carga de datos del titanic `df = sns.load_dataset('titanic')`
#
# "¿Era la tercera clase más 'joven' que la primera? Vamos a comparar la clase del pasajero con su edad. Observa las cajas: ¿Cuál es la que está más arriba en el gráfico? ¿Qué nos dice eso sobre quiénes tenían el dinero para pagar los boletos de primera clase en 1912?"
